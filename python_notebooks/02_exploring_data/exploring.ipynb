# %%
import pandas as pd

# %%
df_2010 = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/cases/cases_2010.csv")

df_2011 = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/cases/cases_2011.csv")

df_2012 = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/cases/cases_2012.csv")

df_2013 = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/cases/cases_2013.csv")

df_2014 = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/cases/cases_2014.csv")

df_2015 = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/cases/cases_2015.csv")

df_2016 = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/cases/cases_2016.csv")

df_2017 = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/cases/cases_2017.csv")

df_2018 = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/cases/cases_2018.csv")

# %%
df_2010
# Out:
#                       ddl_case_id  year  state_code  dist_code  court_no  \
# 0        01-01-01-200308002162010  2010           1          1         1
# 1        01-01-01-200707000172010  2010           1          1         1
# 2        01-01-01-200707000182010  2010           1          1         1
# 3        01-01-01-200707000192010  2010           1          1         1
# 4        01-01-01-200707000202010  2010           1          1         1
# ...                           ...   ...         ...        ...       ...
# 4281322  32-01-01-211900000022010  2010          32          1         1
# 4281323  32-01-01-212400000102010  2010          32          1         1
# 4281324  32-01-01-212500000012010  2010          32          1         1
# 4281325  32-01-01-212600000012010  2010          32          1         1
# 4281326  32-01-01-213000000802010  2010          32          1         1
#
#                      cino                         judge_position  \
# ...

# %%
df_2010['judge_position'].value_counts().head(50)
# Out:
# judge_position
# district and sessions court                         756161
# chief judicial magistrate                           566262
# judicial magistrate court                           425816
# civil court                                         326011
# civil judge senior division                         241252
# civil judge junior division                         237400
# criminal cases                                      215779
# principal district and sessions court               127444
# principal civil judge                               114708
# additional chief judicial magistrate                112442
# chief metropolitan magistrate                        86932
# jmfc                                                 70758
# metropolitan magistrate court                        70754
# principal civil judge senior division                68654
# taluka court                                         67656
# city civil and sessions court                        64325
# ...

# %%
len(df_2010['state_code'].value_counts())
# Out:
# 31

# %%
state_key = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Judicial_DA/data/justice_data/csv/keys/cases_state_key.csv")

# %%
state_key
# Out:
#      year  state_code      state_name pc11_state_name  pc11_state_id
# 0    2018           2  Andhra Pradesh  andhra pradesh             28
# 1    2011           2  Andhra Pradesh  andhra pradesh             28
# 2    2011          29       Telangana  andhra pradesh             28
# 3    2010          29       Telangana  andhra pradesh             28
# 4    2014           2  Andhra Pradesh  andhra pradesh             28
# ..    ...         ...             ...             ...            ...
# 282  2010          16     West Bengal     west bengal             19
# 283  2017          16     West Bengal     west bengal             19
# 284  2013          16     West Bengal     west bengal             19
# 285  2014          16     West Bengal     west bengal             19
# 286  2015          16     West Bengal     west bengal             19
#
# [287 rows x 5 columns]

# %%
state_key[state_key['state_name'] == 'Punjab']
# Out:
#      year  state_code state_name pc11_state_name  pc11_state_id
# 215  2013          22     Punjab          punjab              3
# 216  2010          22     Punjab          punjab              3
# 217  2018          22     Punjab          punjab              3
# 218  2017          22     Punjab          punjab              3
# 219  2011          22     Punjab          punjab              3
# 220  2012          22     Punjab          punjab              3
# 221  2016          22     Punjab          punjab              3
# 222  2015          22     Punjab          punjab              3
# 223  2014          22     Punjab          punjab              3

# %%
df_2010[df_2010['state_code'] == 22]
# Out:
#                       ddl_case_id  year  state_code  dist_code  court_no  \
# 3613256  22-01-01-200100001652016  2010          22          1         1
# 3613257  22-01-01-200100346662013  2010          22          1         1
# 3613258  22-01-01-200100346712013  2010          22          1         1
# 3613259  22-01-01-200100346842013  2010          22          1         1
# 3613260  22-01-01-200100346852013  2010          22          1         1
# ...                           ...   ...         ...        ...       ...
# 3718672  22-26-07-205507000812010  2010          22         26         7
# 3718673  22-26-07-205507000862010  2010          22         26         7
# 3718674  22-26-07-205507001272010  2010          22         26         7
# 3718675  22-26-07-205507002482010  2010          22         26         7
# 3718676  22-26-07-205507002832010  2010          22         26         7
#
#                      cino               judge_position female_defendant  \
# ...

# %% [markdown]
# # total cases from punjab = 5,73,146

# %%
len(df_2010[df_2010['state_code'] == 22]) 
+ len(df_2011[df_2011['state_code'] == 22]) 
+ len(df_2012[df_2012['state_code'] == 22]) 
+ len(df_2013[df_2013['state_code'] == 22]) 
+ len(df_2014[df_2014['state_code'] == 22]) 
+ len(df_2015[df_2015['state_code'] == 22]) 
+ len(df_2016[df_2016['state_code'] == 22]) 
+ len(df_2017[df_2017['state_code'] == 22]) 
+ len(df_2018[df_2018['state_code'] == 22])
# Out:
# 573146
