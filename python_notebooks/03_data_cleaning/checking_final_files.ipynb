# %%
import pandas as pd

# %%
cases_court_key_cleaned = pd.read_csv("processed/export/cases_court_key_cleaned.csv")

# %%
cases_court_key_cleaned = pd.read_csv("processed/export/cases_court_key_cleaned.csv")

# %%
cases_court_key_cleaned = pd.read_csv("processed/export/cases_court_key_cleaned.csv")

# %%
cases_court_key_cleaned = pd.read_csv("processed/export/cases_court_key_cleaned.csv")

# %%
cases_court_key_cleaned = pd.read_csv("processed/export/cases_court_key_cleaned.csv")

# %%
cases_court_key_cleaned = pd.read_csv("processed/export/cases_court_key_cleaned.csv")

# %%
cases_court_key_cleaned = pd.read_csv("processed/export/cases_court_key_cleaned.csv")

# %%
cases_court_key_cleaned = pd.read_csv("processed/export/cases_court_key_cleaned.csv")

# %%
cases_court_key_cleaned = pd.read_csv("processed/export/cases_court_key_cleaned.csv")
